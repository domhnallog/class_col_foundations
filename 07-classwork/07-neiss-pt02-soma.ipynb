# %% [markdown]
# # NEISS, Part 2 (this class)
#
# * **Dataset:** `neiss2017.tsv` (kind of) - NEISS, again! But an old one, because the newer one is too nice.
# * **Source:** https://www.cpsc.gov/Research--Statistics/NEISS-Injury-Data
# * **Topics:**
#     - filtering with `.str.contains` and simple anchored regular expressions
#     - pulling out text with `.str.extract`
#     - pandas display options
#     - joining/merging tables
#     - datetime parsing and manipulation

# %%
import pandas as pd
import numpy as np

# Cut off text columns after 200 characters
pd.set_option("display.max_colwidth", 200)

# %matplotlib inline

# %% [markdown]
# # 0) Read in our data

# %%
df = pd.read_csv("cleaned.csv")
df.head()
# Out:
#    CPSC_Case_Number Treatment_Date   Age     Sex   Race Other_Race  Body_Part  \
# 0         170100733     01/01/2017  21.0    Male  White        NaN       75.0
# 1         170100734     01/01/2017  71.0    Male  White        NaN       31.0
# 2         170100735     01/01/2017  16.0    Male  White        NaN       33.0
# 3         170100737     01/01/2017  55.0  Female  White        NaN       75.0
# 4         170100740     01/01/2017  86.0  Female  White        NaN       79.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               NaN
# 1       53.0             NaN          1.0       5.0               NaN
# 2       51.0             NaN          1.0       1.0               NaN
# 3       62.0             NaN          1.0       1.0               NaN
# 4       58.0             NaN          1.0       1.0               NaN
#
#    Product_1  Product_2  \
# 0     1207.0        NaN
# 1     1807.0        NaN
# 2      676.0      342.0
# 3      620.0        NaN
# 4     1646.0     4056.0
#
#                                                                Narrative_1  \
# 0  21YOM WAS BOXING WITH FRIEND WHILE DRINKING AND GOT PUNCHED IN THE FACE
# 1                        71YOM FELL ON FLOOR IN BATHROOM. DX RIB CONTUSION
# 2               16YOM TRIPPED OVER A RUG AND FELL INTO A BURNING FIREPLACE
# 3  55YOF WAS STANDING ON A STEP STOOL AND LOST FOOTING AND FELL. DX CLOSED
# 4  86YOF GOT TANGLED IN COAT AND FELL BACKWARD STRIKING BACK ON A *** HUTC
#
#                                                  Narrative_2 Stratum   PSU  \
# 0        . BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXICATION       S  46.0
# 1                                                        NaN       S  46.0
# 2  DX BURNS INVOLVING LESS THAN 10% OF BODY SURFACE, FOREARM       S  46.0
# 3                                                HEAD INJURY       S  46.0
# 4                  H. DX HEMATOMA OF SOFT TISSUE, LEFT FLANK       S  46.0
#
#     Weight
# 0  77.6641
# 1  77.6641
# 2  77.6641
# 3  77.6641
# 4  77.6641

# %% [markdown]
# ## 1) Let's only take out punchers
#
# * After we learn this, what else can we do?

# %%
punches = df[df.Narrative_1.str.contains("PUNCH")]
punches.head(2)
# Out:
#     CPSC_Case_Number Treatment_Date   Age   Sex   Race Other_Race  Body_Part  \
# 0          170100733     01/01/2017  21.0  Male  White        NaN       75.0
# 32         170102931     01/01/2017  26.0  Male    NaN        NaN       82.0
#
#     Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0        62.0             NaN          1.0       1.0               NaN
# 32       59.0             NaN          1.0       1.0               NaN
#
#     Product_1  Product_2                                        Narrative_1  \
# 0      1207.0        NaN  21YOM WAS BOXING WITH FRIEND WHILE DRINKING AN...
# 32     1892.0        NaN                 26YOM LAC HAND- PUNCHED GLASS DOOR
#
#                                           Narrative_2 Stratum   PSU   Weight
# 0   . BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXIC...       S  46.0  77.6641
# 32                                                NaN       M  14.0  87.0904

# %%
punches.Sex.value_counts().plot(kind='barh')

# %%
punches.Narrative_1.head(10)
# Out:
# 0      21YOM WAS BOXING WITH FRIEND WHILE DRINKING AND GOT PUNCHED IN THE FACE
# 32                                          26YOM LAC HAND- PUNCHED GLASS DOOR
# 93                         26 YR OLD MALE PUNCHED GLASS WINDOW AND LAC FOREARM
# 129                            25YOM PUNCHED A GLASS DOOR AND CUT HIS FOREARM.
# 163                                 26YOF WITH FRACTURED WRIST, PUNCHED A WALL
# 199         12 YOM INJURED HAND,WRIST,PUNCHING BOXING BAG. DX- CONTUSION RIGHT
# 420    PT HAS RIGHT HAND PAIN AFTER PUNCHING A DOOR   METACARPAL FRACTURE   23
# 634                 LT HAND LAC.  18YOM PUNCHED GLASS WINDOW WITH HAND.  ETOH.
# 635               HAND LAC.  25YOM PUNCHED GLASS DOOR WITH HAND.  ETOH.  LWOT.
# 647                      LT HAND PAIN.  26YOM PAIN IN HAND FROM PUNCHING WALL.
# Name: Narrative_1, dtype: object

# %%
punches.Narrative_1.str.extract("PUNCHED A (.*)").dropna()
# Out:
#                                                               0
# 129                             GLASS DOOR AND CUT HIS FOREARM.
# 163                                                        WALL
# 863                                                   MIRROR: D
# 993                   WALL W/ RIGHT HAND DX: OPEN WOUND OF HAND
# 1073                           WOODEN TABLE SUSTAINED A HAND FX
# 1235                                       FISH TANK WALKED OUT
# 1273                                        MIRROR.  DX HAND FX
# 1828                        GLASS WINDOW DX: OPEN WOUND OF HAND
# 1857                                   WINDOW AND CUT UPPER ARM
# 2176                                  WALL CONTUSION RIGHT HAND
# 2195                             DOOR SUSTAINED A RIGHT HAND FX
# 2196                                  WALL FRACTURED RIGHT HAND
# 2576              MANTEL OUT OF ANGER. C/O HAND PAIN DX HAND FX
# 2762                                    WALL. DX HAND CONTUSION
# 2770            CONCRETE WALL W/ RIGHT HAND DX: RIGHT HAND PAIN
# 2771    BRICK WALL W/ RIGHT HAND & HAS CUTS ON FINGERS DX: RIGH
# 2778                                    WINDOW AND INJURED HAND
# 2818                WINDOW BECAUSE HE WAS ANGRY AND CUT FOREARM
# 2823                                                      WALL.
# 2896     PILLAR 6 DAYS AGO WHEN UPSET ABOUT MOM'S RECENT DEATH;
# 3622                                     PICTURE FRAME IN ANGER
# 3713                          GLASS WINDOW IN FRUSTRATION B/C W
# 3801        DOOR WITH HER RIGHT HAND WHILE ANGRY; HAND FRACTURE
# 3922    WALL AFTER GETTING UPSET W/ GIRLFRIEND WHILE ON PHONE D
# 3989                                                      WALL.
# 4561                                  TELEVISION AND CUT R HAND
# 5165                               WALL CONTUSION TO RIGHT HAND
# 5660                            GLASS DOOR.  DX HAND LACERATION
# 5665                        WALL IN SCHOOL.  DX WRIST CONTUSION
# 5782                        WINDOW WITH CLOSED FIST ON SATURDAY
# ...                                                         ...
# 357350                              WALL DX RIGHT HAND FRACTURE
# 358211                           WALL. DX: CLSOED FX OF RT HAND
# 358346                            WOODEN DOOR DX: HAND ABRASION
# 358835                  DOOR OUT OF ANGER INJURING HAND AT HOME
# 359041                   WALL AND C/O PAIN TO R HAND. / HAND FX
# 359065                                           WALL W/ R HAND
# 359249                        CHAIR IN ANGER. DX HAND FRACTURES
# 359471            GLASS WINDOW IN HIS HOME C/O LAC TO RH DX LAC
# 359517                                                  WALL DX
# 359599   WALL IN ANGER AT JUVENILE DETENTION CTR WHERE HE RESID
# 359751                                WALL & C/O HAND PAIN.  DX
# 360228                  WALL WITH HIS RIGHT HAND; HAND FRACTURE
# 360276       CABINET AT UNSPECIFIED LOCATION. DX HAND CONTUSION
# 360487                 TELEVISION, CUT HAND. DX HAND LACERATION
# 360730                      HOLE THROUGH IT DX CONTUSION R HAND
# 360787     WOODEN DOOR AT HOME WITH HIS RIGHT HAND; HAND INJURY
# 360874                WALL AT HOME NOW HAS PAIN AND SWELLING DX
# 360915              DOG CAGE WITH HAND NOW C/O RIGHT HAND PAIN.
# 360927                                     WALL WITH HIS HANDS;
# 361000                               LOCKER AT SCHOOL; HAND FX.
# 361870      WALL, C/O PAIN/ SWELLING LT PINKY.  DX; BOXERS FX #
# 362269          WALL ABOUT AN HOUR AGO WHILE AT HOME, DX: RIGHT
# 362286            CHAIR 3 DAYS AGO. DX: 2ND METACARPAL NECK FX.
# 362451                                  WALL, AT HOME- RT. HAND
# 362775                    DOOR AND HURT HAND. DX HAND CONTUSION
# 362891                 CHAIR: DX R HAND PN/FX/SPRAIN/CONTU, DIS
# 362933                    POLE AND INJURED HAND. DX HAND SPRAIN
# 363388                           DOOR C BOTH HANDS IN ANGER YTD
# 363603                                                  WINDOW.
# 363869                                         WALL. DX HAND FX
#
# [1950 rows x 1 columns]

# %%
codes = pd.read_csv("neiss_fmt.txt", sep='\t')
codes = codes[codes['Format name'] == 'PROD']
#codes['Starting value for format'] = codes['Starting value for format'].astype(str).str.zfill(4)
codes.head()
# Out:
#     Format name  Starting value for format  Ending value for format  \
# 112        PROD                        101                      101
# 113        PROD                        102                      102
# 114        PROD                        103                      103
# 115        PROD                        106                      106
# 116        PROD                        107                      107
#
#                                           Format value label
# 112  101 - WASHING MACHINES WITHOUT WRINGERS OR OTHER DRYERS
# 113                           102 - WRINGER WASHING MACHINES
# 114         103 - WASHING MACHINES WITH UNHEATED SPIN DRYERS
# 115            106 - ELECTRIC CLOTHES DRYERS WITHOUT WASHERS
# 116                 107 - GAS CLOTHES DRYERS WITHOUT WASHERS

# %%
merged = punches.merge(codes, left_on='Product_1', right_on='Starting value for format')
merged.head()
# Out:
#    CPSC_Case_Number Treatment_Date   Age   Sex   Race Other_Race  Body_Part  \
# 0         170100733     01/01/2017  21.0  Male  White        NaN       75.0
# 1         170106918     01/01/2017  12.0  Male  Black        NaN       82.0
# 2         170121705     01/07/2017  34.0  Male    NaN        NaN       82.0
# 3         170133172     01/08/2017  17.0  Male    NaN        NaN       82.0
# 4         170153163     01/24/2017  15.0  Male    NaN        NaN       75.0
#
#    Diagnosis Other_Diagnosis  Disposition  ...  Product_2  \
# 0       62.0             NaN          1.0  ...        NaN
# 1       53.0             NaN          1.0  ...        NaN
# 2       57.0             NaN          1.0  ...        NaN
# 3       53.0             NaN          1.0  ...        NaN
# 4       62.0             NaN          1.0  ...        NaN
#
#                                                                Narrative_1  \
# 0  21YOM WAS BOXING WITH FRIEND WHILE DRINKING AND GOT PUNCHED IN THE FACE
# 1       12 YOM INJURED HAND,WRIST,PUNCHING BOXING BAG. DX- CONTUSION RIGHT
# 2  34YOM C/O R HAND PN INJ W PUNCHING HVY BAG W WORK' OUT: DX FX METACARPA
# 3   17YOM WAS PUNCHING A PUNCHING BAG AND SUSTAINED A RIGHT HAND CONTUSION
# 4  15YM WAS BOXING IN FULL GEARS, PUNCHED TO BACK OF HEAD,-LOC YET DIZZINE
#
#                                            Narrative_2  Stratum   PSU  \
# 0  . BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXICATION        S  46.0
# 1                                           HAND,WRIST        M  78.0
# 2                                                    L        V  67.0
# 3                                                  NaN        V   2.0
# 4                                    SS&HEAD PAIN>>CHI        V  21.0
#
#     Weight Format name  Starting value for format  Ending value for format  \
# 0  77.6641        PROD                       1207                     1207
# 1  87.0904        PROD                       1207                     1207
# 2  16.1828        PROD                       1207                     1207
# 3  16.1828        PROD                       1207                     1207
# 4  16.1828        PROD                       1207                     1207
#
#                                Format value label
# 0  1207 - BOXING (ACTIVITY, APPAREL OR EQUIPMENT)
# 1  1207 - BOXING (ACTIVITY, APPAREL OR EQUIPMENT)
# 2  1207 - BOXING (ACTIVITY, APPAREL OR EQUIPMENT)
# 3  1207 - BOXING (ACTIVITY, APPAREL OR EQUIPMENT)
# 4  1207 - BOXING (ACTIVITY, APPAREL OR EQUIPMENT)
#
# [5 rows x 23 columns]

# %%
merged['Format value label'].value_counts().head(20)
# Out:
# 1884 - CEILINGS AND WALLS (INTERIOR PART OF COMPLETED STRUCTURE)       2002
# 1894 - WINDOWS AND WINDOW GLASS, OTHER THAN STORM WINDOWS               541
# 1893 - DOORS, OTHER OR NOT SPECIFIED                                    290
# 1207 - BOXING (ACTIVITY, APPAREL OR EQUIPMENT)                          178
# 4004 - MIRRORS OR MIRROR GLASS                                          123
# 276 - REFRIGERATORS                                                      63
# 1807 - FLOORS OR FLOORING MATERIALS                                      62
# 572 - TELEVISIONS                                                        60
# 1865 - POLES                                                             59
# 1892 - GLASS DOORS OR DOORS WITH GLASS PANELS                            58
# 1726 - LOCKERS                                                           52
# 4056 - CABINETS, RACKS, ROOM DIVIDERS AND SHELVES, NEC                   44
# 604 - DESKS, CHESTS, BUREAUS OR BUFFETS                                  43
# 4057 - TABLES (EXCL.  BABY CHANGING TABLES, BILLIARD OR POOL TABLES      31
# 1871 - FENCES OR FENCE POSTS                                             24
# 652 - PICTURES, PICTURE FRAMES OR WALL DECORATIONS                       24
# 1205 - BASKETBALL, ACTIVITY AND RELATED EQUIPMENT                        18
# 4074 - CHAIRS, OTHER OR NOT SPECIFIED                                    17
# 4076 - BEDS OR BEDFRAMES, OTHER OR NOT SPECIFIED                         15
# 3257 - MARTIAL ARTS (ACTIVITY, APPAREL OR EQUIPMENT)                     15
# Name: Format value label, dtype: int64

# %% [markdown]
# ## 2) Let's only take out _wall_ punchers
#
# * After we learn this, what else can we do?

# %% [markdown]
# ## 3) What month do people punch walls in?
#
# * After we learn this, what else can we do?

# %% [markdown]
# ## 4) What else do people punch?
#
# * After we learn this, what else can we do?
