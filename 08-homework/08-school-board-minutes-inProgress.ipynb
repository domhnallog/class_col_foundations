# %% [markdown]
# # School Board Minutes
#
# Scrape all of the school board minutes from http://www.mineral.k12.nv.us/pages/School_Board_Minutes
#
# Save a CSV called `minutes.csv` with the date and the URL to the file. The date should be formatted as YYYY-MM-DD.
#
# **Bonus:** Download the PDF files
#
# **Bonus 2:** Use [PDF OCR X](https://solutions.weblite.ca/pdfocrx/index.php) on one of the PDF files and see if it can be converted into text successfully.
#
# * **Hint:** If you're just looking for links, there are a lot of other links on that page! Can you look at the link to know whether it links or minutes or not? You'll want to use an "if" statement.
# * **Hint:** You could also filter out bad links later on using pandas instead of when scraping
# * **Hint:** If you get a weird error that you can't really figure out, you can always tell Python to just ignore it using `try` and `except`, like below. Python will try to do the stuff inside of 'try', but if it hits an error it will skip right out.
# * **Hint:** Remember the codes at http://strftime.org
# * **Hint:** If you have a date that you've parsed, you can use `.dt.strftime` to turn it into a specially-formatted string. You use the same codes (like %B etc) that you use for converting strings into dates.
#
# ```python
# try:
#   blah blah your code
#   your code
#   your code
# except:
#   pass
# ```

# %%
import requests
import re
import pandas as pd
import numpy as np
from datetime import datetime
from bs4 import BeautifulSoup

# %%
url = "http://www.mineral.k12.nv.us/pages/School_Board_Minutes"
raw_html = requests.get(url).content
soup_doc = BeautifulSoup(raw_html, "html.parser")
print(type(soup_doc))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
### TEST VIEWS OF DATA
# raw_html
# print(soup_doc)
# print(soup_doc.prettify())

# %%
### CODE BROKE BECAUSE OF MISORDERED TAGS IN 2018
links = soup_doc.find_all('a')
# links[25]
# links[25]['href']
# links[25].string
# links[25].text
# links[25]['span']
# links[25]['color']

# for link in links:
#     if 'pdf' in link['href']:
#         print(link.string)
#         print(link['href'])
#         print(link['span'])
#         print('====================================================================')

# %%
### CONTINUED TESTING AROUND HREF
links = soup_doc.find_all('a')
# links[25]
# links[25]['href']
# links[25].string
# links[25].text
# links[25]['span']
# links[25]['color']

for link in links:
    if 'pdf' in link['href']:
        print('GOOD GOOD GOOD')
#         print(link)
        print(link.parent)
    else:
        print('no pdf')
        print(link.parent)
#         print(link.string)
#         print(link['href'])
#         print(link['span'])
    print('====================================================================')
# Out:
# no pdf
# <td> | <strong></strong><a href="https://nvcloud1.infinitecampus.org/campus/portal/mineral.jsp"><strong> Infinit Campus Parent/Student Portal</strong></a> | <strong></strong><a href="https://nvcloud1.infinitecampus.org/campus/mineral.jsp"><strong> Infinite Campus Teacher Portal</strong></a> | <a href="http://mail.mineral.k12.nv.us/"><strong>Web Email</strong></a> | </td>
# ====================================================================
# no pdf
# <td> | <strong></strong><a href="https://nvcloud1.infinitecampus.org/campus/portal/mineral.jsp"><strong> Infinit Campus Parent/Student Portal</strong></a> | <strong></strong><a href="https://nvcloud1.infinitecampus.org/campus/mineral.jsp"><strong> Infinite Campus Teacher Portal</strong></a> | <a href="http://mail.mineral.k12.nv.us/"><strong>Web Email</strong></a> | </td>
# ====================================================================
# no pdf
# <td> | <strong></strong><a href="https://nvcloud1.infinitecampus.org/campus/portal/mineral.jsp"><strong> Infinit Campus Parent/Student Portal</strong></a> | <strong></strong><a href="https://nvcloud1.infinitecampus.org/campus/mineral.jsp"><strong> Infinite Campus Teacher Portal</strong></a> | <a href="http://mail.mineral.k12.nv.us/"><strong>Web Email</strong></a> | </td>
# ====================================================================
# no pdf
# <li><a href="/">Home</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/School_Board_Connection" id="menu_7" onmouseout="hide_drop_down_menu('drop_down_menu_7', 'menu_7')" onmouseover="show_drop_down_menu('drop_down_menu_7', 'menu_7')">School Board</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/livesite_template_overview" id="menu_2" menu_3"="" onmouseout="hide_drop_down_menu('drop_down_menu_3', 'menu_3')" onmouseover="show_drop_down_menu('drop_down_menu_3', 'menu_3')">Schools</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/new_releases" id="menu_5" onmouseout="hide_drop_down_menu('drop_down_menu_5', 'menu_5')" onmouseover="show_drop_down_menu('drop_down_menu_5', 'menu_5')">Students</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/livesite_template_overview" id="menu_6" onmouseout="hide_drop_down_menu('drop_down_menu_6', 'menu_6')" onmouseover="show_drop_down_menu('drop_down_menu_6', 'menu_6')">Parents</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/district_office" id="menu_1" onmouseout="hide_drop_down_menu('drop_down_menu_1', 'menu_1')" onmouseover="show_drop_down_menu('drop_down_menu_1', 'menu_1')">District</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/transportation" id="menu_10" onmouseout="hide_drop_down_menu('drop_down_menu_10', 'menu_10')" onmouseover="show_drop_down_menu('drop_down_menu_10', 'menu_10')">Transportation</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/Maintenance" id="menu_12" onmouseout="hide_drop_down_menu('drop_down_menu_12', 'menu_12')" onmouseover="show_drop_down_menu('drop_down_menu_12', 'menu_12')">Maintenance</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/finance" id="menu_10" onmouseout="hide_drop_down_menu('drop_down_menu_10', 'menu_10')" onmouseover="show_drop_down_menu('drop_down_menu_10', 'menu_10')">Finance</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/Committees" id="menu_9" onmouseout="hide_drop_down_menu('drop_down_menu_9', 'menu_9')" onmouseover="show_drop_down_menu('drop_down_menu_9', 'menu_9')">Committees</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/employment" id="menu_11" onmouseout="hide_drop_down_menu('drop_down_menu_11', 'menu_11')" onmouseover="show_drop_down_menu('drop_down_menu_11', 'menu_11')">Employment</a></li>
# ====================================================================
# no pdf
# <li><a href="/pages/Community_Links" id="menu_12" onmouseout="hide_drop_down_menu('drop_down_menu_12', 'menu_12')" onmouseover="show_drop_down_menu('drop_down_menu_12', 'menu_12')">Community</a></li>
# ====================================================================
# <span style="color: #000000; font-family: 'times new roman', times; font-size: medium;"><a href="/files/4.12.17_minutes.pdf"><span style="background-color: #ffffff; color: #000000;">April 12, 2017</span></a></span>
# ====================================================================
# GOOD GOOD GOOD
# <span style="font-family: 'times new roman', times; font-size: medium; color: #000000;"><a href="/files/5.1.17_Minutes.pdf"><span style="background-color: #ffffff; color: #000000;">May 1, 2017</span></a></span>
# ====================================================================
# GOOD GOOD GOOD
# <span style="background-color: #ffffff;"><a href="/files/5.4.17_minutes.pdf"><span style="color: #000000;">May 4, 2017</span></a></span>
# ====================================================================
# ------------------------------------------------------
# KeyError             Traceback (most recent call last)
# <ipython-input-5-34ff19862e67> in <module>
#       9
#      10 for link in links:
# ---> 11     if 'pdf' in link['href']:
#      12         print('GOOD GOOD GOOD')
#      13 #         print(link)
#
# C:\Program Files (x86)\Python37-32\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1014         """tag[key] returns the value of the 'key' attribute for the tag,
#    1015         and throws an exception if it's not there."""
# -> 1016         return self.attrs[key]
#    1017
#    1018     def __iter__(self):
#
# KeyError: 'href'

# %%
### INDIVIDUAL LINE TESTS
# string = string.replace(u'\xa0', u'')
# paras = soup_doc.find_all('p')[19:78]
# links
# paras[1]
# paras[1].contents
# paras[1].find('a')
# paras[1].a['href']

# %%
### WORKING CODE WITH DIRTY RESPONSES
# minutes_list = []
# paras = soup_doc.find_all('p')[19:78]
# for para in paras[1:]:
#     minutes = []
#     date = para.text.replace(u'\xa0', u'')
#     minutes.append(date)
#     if para.find('a'):
#         url = para.a['href']
#     else:
#         url = 'http://'
#     minutes.append(url)
#     minutes_list.append(minutes)
# minutes_list

# %%
### WORKING WITH DELETED ROWS
minutes_list = []
paras = soup_doc.find_all('p')[19:78]
for para in paras[1:]:
    minutes = []
    date = para.text.replace(u'\xa0', u'')
    if not date: 
        pass
    elif 'Meeting' in date:
        pass
    else:
        minutes.append(date)
        if para.find('a'):
            url = para.a['href']
        else:
            url = ''
        minutes.append(url)
        minutes_list.append(minutes)
minutes_list.insert(0,['date','url'])
minutes_list
# Out:
# [['date', 'url'],
#  ['June 4, 2019', '/files/6.4.19_minutes.pdf'],
#  ['May 28, 2019', '/files/5.28.19_minutes.pdf'],
#  ['May 21, 2019 CANCELLED', ''],
#  ['May 7, 2019', '/files/5.7.19_minutes.pdf'],
#  ['April 23, 2019', '/files/4.23.19_minutes.pdf'],
#  ['April 8, 2019', '/files/4.8.19_minutes.pdf'],
#  ['March 19, 2019', '/files/3.5.19_minutes.pdf'],
#  ['March 5, 2019', '/files/3.5.19.pdf'],
#  ['February 26, 2019', '/files/2.26.19_minutes.pdf'],
#  ['February 5, 2019', '/files/2.5.19_minutes.pdf'],
#  ['January 22, 2019', '/files/January_22_minutes.pdf'],
#  ['January 8, 2019', '/files/January_8_minutes.pdf'],
#  ['December 20, 2018', '/files/12.20.18_minutes.pdf'],
#  ['December 4, 2018', '/files/12.4.18_minutes.pdf'],
#  ['November 20, 2018', '/files/11.20.18.pdf'],
#  ['November 7, 2018', ''],
#  ['October 16, 2018', ''],
#  ['September 25, 2018', '/files/9.25.18_minutes.pdf'],
#  ['September 13, 2018', '/files/9.13.18_minutes.pdf'],
#  ['September 4, 2018', '/files/9.4.18.pdf'],
#  ['August 21, 2018', '/files/8.21.18_minutes.pdf'],
#  ['August 7, 2018', '/files/8.7.18_minutes.pdf'],
#  ['July 24, 2018', '/files/7.24.18_minutes.pdf'],
#  ['July 10, 2018', '/files/7.10.18_minutes.pdf'],
#  ['June 28, 2018', '/files/6.28.18.pdf'],
#  ['June 22, 2018', '/files/6.22.18_minutes.pdf'],
#  ['June 21, 2018', '/files/6.21.18.pdf'],
#  ['June 19, 2108 ', '/files/6.19.18_minutes.pdf'],
#  ['June 6, 2018', ''],
#  ['May 29, 2018', '/files/5.29.18_minutes.pdf'],
#  ['May 22,2018', ''],
#  ['May 15, 2018Canceled', ''],
#  ['May 1, 2018', ''],
#  ['April 17, 2018', '/files/4.17.18.pdf'],
#  ['April 2, 2018 ', '/files/april_2,_2018_minutes.pdf'],
#  ['March 27, 2018', ''],
#  ['March 22, 2018', ''],
#  ['March 20, 2018', ''],
#  ['March 8, 2018', '/files/3.8.18.pdf'],
#  ['March 6, 2018', '/files/march_6,_2018_minutes.pdf'],
#  ['February 20, 2018', '/files/feb_20,_2108_minutes.pdf'],
#  ['February 6, 2018', '/files/2.6.18_minutes.pdf'],
#  ['January 16, 2018', '/files/january_16,_2018_minutes.pdf'],
#  ['January 2, 2018', '/files/2.6.18_minutes.pdf'],
#  ['January 5, 2017', '/files/1.5.17_minutes.pdf'],
#  ['January 26, 2017', '/files/1.26.17_minutes.pdf'],
#  ['February 2, 2017', '/files/2.2.17_minutes.pdf'],
#  ['February 16, 2017', '/files/2.16.17_minutes.pdf'],
#  ['March 2, 2017', '/files/3.2.17__minutes.pdf'],
#  ['March 16, 2017', '/files/3.16.17_minutes.pdf'],
#  ['April 12, 2017', '/files/4.12.17_minutes.pdf'],
#  ['May 1, 2017', '/files/5.1.17_Minutes.pdf'],
#  ['May 4, 2017', '/files/5.4.17_minutes.pdf']]

# %%
### ABANDONED STRIP ATTEMPT, SWITCHING TO PANDAS FOR CLEANUP
# minutes_list = []
# paras = soup_doc.find_all('p')[19:78]
# for para in paras[1:]:
#     minutes = []
#     date = para.text.replace(u'\xa0', u'')
#     if not date: 
#         pass
#     elif 'Meeting' in date:
#         pass
#     else:
#         comment = re.findall(r"\d\d\d\d(.*)", date)
#         date = re.findall(r"(.* \d\d\d\d)", date)
# #         date = datetime.strptime(date, '%B %d, %Y')
#         if para.find('a'):
#             url = para.a['href']
#         else:
#             comment.append('missing link')
#         minutes.append(url)
#         minutes.append(date)
#         minutes.append(comment)
#         minutes_list.append(minutes)
# minutes_list.insert(0,['date','url','comment'])
# minutes_list
### *************************************************************************************************************

# %%
type(minutes_list[13][1])
# Out:
# str

# %%
df = pd.DataFrame(minutes_list)
df.columns = df.iloc[0]
df = df[1:]
df
# Out:
# 0                     date                                  url
# 1             June 4, 2019            /files/6.4.19_minutes.pdf
# 2             May 28, 2019           /files/5.28.19_minutes.pdf
# 3   May 21, 2019 CANCELLED
# 4              May 7, 2019            /files/5.7.19_minutes.pdf
# 5           April 23, 2019           /files/4.23.19_minutes.pdf
# 6            April 8, 2019            /files/4.8.19_minutes.pdf
# 7           March 19, 2019            /files/3.5.19_minutes.pdf
# 8            March 5, 2019                    /files/3.5.19.pdf
# 9        February 26, 2019           /files/2.26.19_minutes.pdf
# 10        February 5, 2019            /files/2.5.19_minutes.pdf
# 11        January 22, 2019        /files/January_22_minutes.pdf
# 12         January 8, 2019         /files/January_8_minutes.pdf
# 13       December 20, 2018          /files/12.20.18_minutes.pdf
# 14        December 4, 2018           /files/12.4.18_minutes.pdf
# 15       November 20, 2018                  /files/11.20.18.pdf
# 16        November 7, 2018
# 17        October 16, 2018
# 18      September 25, 2018           /files/9.25.18_minutes.pdf
# 19      September 13, 2018           /files/9.13.18_minutes.pdf
# 20       September 4, 2018                    /files/9.4.18.pdf
# 21         August 21, 2018           /files/8.21.18_minutes.pdf
# 22          August 7, 2018            /files/8.7.18_minutes.pdf
# 23           July 24, 2018           /files/7.24.18_minutes.pdf
# 24           July 10, 2018           /files/7.10.18_minutes.pdf
# 25           June 28, 2018                   /files/6.28.18.pdf
# 26           June 22, 2018           /files/6.22.18_minutes.pdf
# 27           June 21, 2018                   /files/6.21.18.pdf
# 28          June 19, 2108            /files/6.19.18_minutes.pdf
# 29            June 6, 2018
# 30            May 29, 2018           /files/5.29.18_minutes.pdf
# 31             May 22,2018
# 32    May 15, 2018Canceled
# 33             May 1, 2018
# 34          April 17, 2018                   /files/4.17.18.pdf
# 35          April 2, 2018      /files/april_2,_2018_minutes.pdf
# 36          March 27, 2018
# 37          March 22, 2018
# 38          March 20, 2018
# 39           March 8, 2018                    /files/3.8.18.pdf
# 40           March 6, 2018     /files/march_6,_2018_minutes.pdf
# 41       February 20, 2018      /files/feb_20,_2108_minutes.pdf
# 42        February 6, 2018            /files/2.6.18_minutes.pdf
# 43        January 16, 2018  /files/january_16,_2018_minutes.pdf
# 44         January 2, 2018            /files/2.6.18_minutes.pdf
# 45         January 5, 2017            /files/1.5.17_minutes.pdf
# 46        January 26, 2017           /files/1.26.17_minutes.pdf
# 47        February 2, 2017            /files/2.2.17_minutes.pdf
# 48       February 16, 2017           /files/2.16.17_minutes.pdf
# 49           March 2, 2017           /files/3.2.17__minutes.pdf
# 50          March 16, 2017           /files/3.16.17_minutes.pdf
# 51          April 12, 2017           /files/4.12.17_minutes.pdf
# 52             May 1, 2017            /files/5.1.17_Minutes.pdf
# 53             May 4, 2017            /files/5.4.17_minutes.pdf

# %%
df['comment'] = df.date.str.extract(r'\d{4}(.*)', expand=False).str.strip().str.lower()
df['date'] = df.date.str.extract(r'(.*\d{4})', expand=False)
df['date'] = df['date'].replace('\s', '', regex=True)
df['date'] = pd.to_datetime(df['date'],format='%B%d,%Y') 
df
# Out:
# 0        date                                  url    comment
# 1  2019-06-04            /files/6.4.19_minutes.pdf
# 2  2019-05-28           /files/5.28.19_minutes.pdf
# 3  2019-05-21                                       cancelled
# 4  2019-05-07            /files/5.7.19_minutes.pdf
# 5  2019-04-23           /files/4.23.19_minutes.pdf
# 6  2019-04-08            /files/4.8.19_minutes.pdf
# 7  2019-03-19            /files/3.5.19_minutes.pdf
# 8  2019-03-05                    /files/3.5.19.pdf
# 9  2019-02-26           /files/2.26.19_minutes.pdf
# 10 2019-02-05            /files/2.5.19_minutes.pdf
# 11 2019-01-22        /files/January_22_minutes.pdf
# 12 2019-01-08         /files/January_8_minutes.pdf
# 13 2018-12-20          /files/12.20.18_minutes.pdf
# 14 2018-12-04           /files/12.4.18_minutes.pdf
# 15 2018-11-20                  /files/11.20.18.pdf
# 16 2018-11-07
# 17 2018-10-16
# 18 2018-09-25           /files/9.25.18_minutes.pdf
# 19 2018-09-13           /files/9.13.18_minutes.pdf
# 20 2018-09-04                    /files/9.4.18.pdf
# 21 2018-08-21           /files/8.21.18_minutes.pdf
# 22 2018-08-07            /files/8.7.18_minutes.pdf
# 23 2018-07-24           /files/7.24.18_minutes.pdf
# 24 2018-07-10           /files/7.10.18_minutes.pdf
# 25 2018-06-28                   /files/6.28.18.pdf
# 26 2018-06-22           /files/6.22.18_minutes.pdf
# 27 2018-06-21                   /files/6.21.18.pdf
# 28 2108-06-19           /files/6.19.18_minutes.pdf
# 29 2018-06-06
# 30 2018-05-29           /files/5.29.18_minutes.pdf
# 31 2018-05-22
# 32 2018-05-15                                        canceled
# 33 2018-05-01
# 34 2018-04-17                   /files/4.17.18.pdf
# 35 2018-04-02     /files/april_2,_2018_minutes.pdf
# 36 2018-03-27
# 37 2018-03-22
# 38 2018-03-20
# 39 2018-03-08                    /files/3.8.18.pdf
# 40 2018-03-06     /files/march_6,_2018_minutes.pdf
# 41 2018-02-20      /files/feb_20,_2108_minutes.pdf
# 42 2018-02-06            /files/2.6.18_minutes.pdf
# 43 2018-01-16  /files/january_16,_2018_minutes.pdf
# 44 2018-01-02            /files/2.6.18_minutes.pdf
# 45 2017-01-05            /files/1.5.17_minutes.pdf
# 46 2017-01-26           /files/1.26.17_minutes.pdf
# 47 2017-02-02            /files/2.2.17_minutes.pdf
# 48 2017-02-16           /files/2.16.17_minutes.pdf
# 49 2017-03-02           /files/3.2.17__minutes.pdf
# 50 2017-03-16           /files/3.16.17_minutes.pdf
# 51 2017-04-12           /files/4.12.17_minutes.pdf
# 52 2017-05-01            /files/5.1.17_Minutes.pdf
# 53 2017-05-04            /files/5.4.17_minutes.pdf

# %%
with open('08-school-board-minutes-cleaned.csv', 'w') as outputfile:
    writer = csv.writer(outputfile)
    writer.writerows(all_rows_bonus)

# %%
df = pd.read_csv("08-school-board-minutes-cleaned.csv")
df.head()
