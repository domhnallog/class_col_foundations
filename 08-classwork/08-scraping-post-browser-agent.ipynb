# %% [markdown]
# ## Maryland Licensing & POST

# %%
import requests
import re
from bs4 import BeautifulSoup

# %%
# url = "https://www.dllr.state.md.us/cgi-bin/ElectronicLicensing/OP_Search/OP_search.cgi"
# response = requests.get(url, verify=False)
# soup_doc = BeautifulSoup(response, "html.parser")

# %%
# calling_app: BAR::BAR_personal_name
# search_page: BAR::BAR_personal_name
# from_self: true
# unit: 16
# html_title: Barbers
# error_contact: Division of Occupational and Professional Licensing
# lastname: smith
# city: 
# Submit: Search

data = {
    'calling_app': 'BAR::BAR_personal_name',
    'search_page': 'BAR::BAR_personal_name',
    'from_self': 'true',
    'unit': '16',
    'html_title': 'Barbers',
    'error_contact': 'Division of Occupational and Professional Licensing',
    'lastname': 'smith',
    'city': '',
    'Submit': 'Search',
}


# Can alsos copy curl 
# Use https://curl.trillworks.com/ to convert to python

# %%
# url = "https://www.dllr.state.md.us/cgi-bin/ElectronicLicensing/OP_Search/OP_search.cgi"
# response = requests.post(url, data=data, verify=False)
# soup_doc = BeautifulSoup(response, "html.parser")

url = 'https://www.dllr.state.md.us/cgi-bin/ElectronicLicensing/OP_Search/OP_search.cgi'
response = requests.post(url, data=data, verify=False)
# Out:
# C:\Program Files (x86)\Python37-32\lib\site-packages\urllib3\connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
response.text

# %%
doc = BeautifulSoup(response.text)
rows = doc.find_all('tr')
for row in rows:
    print(row.text)
# Out:
# Name City
# State
# Zip
# Expiration
# Category
# Reg. #
#
#
# AARON VICTOR SMITH
# CUMBERLAND
# MD
# 21502
# 2020-10-06
# MASTER BARBER
# 17449
#
#
# AMY FOWLER SMITH
# GLEN BURNIE
# MD
# 21061
# 2020-05-08
# MASTER BARBER
# 431
#
#
# BOBBY DWAYNE SMITH
# DISTRICT HEIGHTS
# MD
# 20747
# 2020-10-15
# MASTER BARBER
# 103877
#
#
# BRIAN KELVIN SMITH
# UPPER MARLBORO
# MD
# 20774
# 2020-11-16
# MASTER BARBER
# 13507
#
#
# CAMERON SMITH
# LANHAM
# MD
# 20706
# 2020-10-04
# BARBER
# 107861
#
#
# CARL OTTO SMITH
# BALTIMORE
# MD
# 21206
# 2019-10-28
# BARBER
# 104693
#
#
# CAROL ANN SMITH
# DAMASCUS
# MD
# 20872
# 2020-04-13
# MASTER BARBER
# 7027
#
#
# CAROL ANN SMITH
# NAPLES
# FL
# 34104
# 2021-04-11
# MASTER BARBER
# 7733
#
#
# CHARLES W E SMITH
# FORESTVILLE
# MD
# 20747
# 2020-04-15
# BARBER
# 105439
#
#
# CHARLES SMITH
# BALTIMORE
# MD
# 21218
# 2020-09-24
# BARBER
# 107785
#
#
# CHRISTOPHER EDWARD SMITH
# WASHINGTON
# DC
# 20002
# 2019-09-16
# MASTER BARBER
# 15962
#
#
# DARREL LAMARR SMITH
# NEW CARROLLTN
# MD
# 20784
# 2019-12-05
# BARBER
# 101308
#
#
# DAVID SMITH
# CAPITOL HEIGHTS
# MD
# 20785
# 2020-08-12
# BARBER
# 107799
#
#
# DAVID A SMITH
# BALTIMORE
# MD
# 21207
# 2020-06-16
# MASTER BARBER
# 214714
#
#
# BARBER
# 106250
#
#
# ROBERT T SMITH
# TEMPLE HILL
# MD
# 20748
# 2021-05-13
# MASTER BARBER
# 1827
#
#
# RODNEY O SMITH
# LEXINGTON PARK
# MD
# 20653
# 2021-03-19
# BARBER
# 201494
#
#
# ROGER V. SMITH
# GATES
# NC
# 27937
# 2021-04-18
# BARBER
# 103203
#
#
# ROLAND K SMITH
# BALTIMORE
# MD
# 21216
# 2021-03-06
# BARBER
# 18209
#
#
# RONAL LEE SMITH
# FROSTBURG
# MD
# 21532
# 2021-02-26
# MASTER BARBER
# 5927
#
#
# RUSSLIN V SMITH
# BALTIMORE
# MD
# 21223
# 2020-12-18
# BARBER
# 16095
#
#
# RYAN JOSEPH SMITH
# NOTTINGHAM
# MD
# 21236
# 2019-10-23
# BARBER
# 105971
#
#
# STACEY MARIE SMITH
# PASADENA
# MD
# 21122
# 2019-07-31
# BARBER
# 103347

# %% [markdown]
# ## H&M & Spoofing a Browser's User Agent

# %%
# google "user agent string" in a browser, and get that or mimic other browsers

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'
}

response = requests.get('https://www2.hm.com/en_us/sale/home/view-all.html', headers=headers)
doc = BeautifulSoup(response.text)

# %%
response = requests.get('https://www2.hm.com/en_us/sale/home/view-all.html', headers=headers)
hm_doc = BeautifulSoup(response.text)

# %%
# response.text
# Out:
# '<!DOCTYPE HTML>\r\n<html lang="en" class="no-js en-us" ng-app="hmApp">\r\n    <head>\n   \r\n       \r\n \r\n<link rel="stylesheet" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/general.min.11.0.156.css" type="text/css">\n<script type="text/javascript" src="/dtagent_ICA23STVbpr_7000100201011.js" data-dtconfig="agentUri=/dtagent_ICA23STVbpr_7000100201011.js|rid=RID_2058009299|rpid=-1752489573|domain=hm.com|rt=10000|bandwidth=300_m|lastModification=1554533217263|lab=1|tp=500,50,3,1,10|reportUrl=dynaTraceMonitor|app=H&M Production Web"></script><script>\r\nvar hm_deviceType="desktop";\r\n</script>\r\n<!--[if lt IE 9]>\r\n<link rel="stylesheet" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/ie8.min.css" type="text/css">\n<script type="text/javascript" src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/ie8.min.js"></script>\n<![endif]-->\r\n<script type="text/javascript" src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/jquery.min.js"></script>\n<script type="text/javascript" src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/head.min.11.0.156.js"></script>\n<!-- to include grunticon -->\r\n<script>var clientlibsVersion = \'.11.0.156\';</script>\r\n   <noscript><link rel="stylesheet" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/icons/svg.min.11.0.156.css" type="text/css">\n</noscript>\r\n<!-- to include grunticon -->\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n\t<script type="text/javascript"></script><script src="https://cdn-pci.optimizely.com/public/2125530039/s/hm_us.js"></script>\n    <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n\n    <meta name="viewport" content="width=1000">\n    \r\n\t<meta name="contentPath" content="/en_us/sale/shop-by-product-home/view-all"/> \r\n    <meta name="keywords"/>\r\n    <meta name="description" content="View all products on sale at outstanding prices at H&amp;M Home. Don&#39;t miss out on the H&amp;M sale - find the best deals online or in-store."/>\r\n    <meta property="og:title" content="Interior decoration &amp; design on sale online | H&amp;M US"/>\t\r\n    <meta property="og:description" content="View all products on sale at outstanding prices at H&amp;M Home. Don&#39;t miss out on the H&amp;M sale - find the best deals online or in-store."/>\r\n<meta property="og:site_name" content="H&amp;M">\n\t<meta property="og:type" content="website">\n\t<meta property="og:url" content="https://www2.hm.com/en_us/sale/home/view-all.html">\n    <meta property="og:image" content="https://www2.hm.com/content/dam/courtesypageimages/down_for_maintenance.jpeg" >\n\t<meta property="fb:app_id" content="1433700643510498" >\n    <link rel="icon" type="image/vnd.microsoft.icon" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/favicon/favicon.ico">\n    <link rel="shortcut icon" type="image/vnd.microsoft.icon" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/favicon/favicon.ico">\n\n\n     <link rel="canonical" href="https://www2.hm.com/en_us/sale/home/view-all.html"/>\n        \t<link rel="alternate" media="only screen and (max-width: 640px)" href="https://m2.hm.com/m/en_us/sale/home/view-all.html">\n\t\t\r\n    <title>Interior decoration &amp; design on sale online | H&amp;M US</title>\r\n<script type="text/javascript" src="/en_us/metrics/default/touchpoint.js"></script>\r\n       \r\n    \r\n        <meta property="og:open_graph_title"/>\r\n\t    <meta property="og:open_graph_description"/>\r\n\t    <meta property="og:open_graph_url"/>\r\n\t    <meta property="og:open_graph_image"/>\r\n\t    <meta property="og:open_graph_video"/>\r\n</head><body ng-controller="HmAppController" ng-class="{pre_shopping_sale_countdown:preshoppingStartingSoon}" class="subdepartment-page">\r\n\t<div class="dictionary parbase"></div>\n<script type="text/javascript">\r\n\r\n        var hm = hm || {}; \r\n        hm.options = hm.options || {}; ...

# %%
items = hm_doc.find_all('h3', class_='item-heading')
for item in items:
    print(item.text.strip())
# Out:
# Knit Throw with Fringe
# Patterned Duvet Cover
# Cotton Pillowcase
# Pillowcase with Pin-tucks
# Linen-blend Bedspread
# Cotton Satin Duvet Cover
# Cotton Satin Duvet Cover
# Cotton Percale Duvet Cover
# Cotton Satin Duvet Cover
# Cotton Satin Duvet Cover
# King/Queen Duvet Cover
# Oxford-style Pillowcase
# Jacquard-weave Duvet Cover
# Large Glass Vase
# Cotton Percale Duvet Cover
# Cotton Satin Pillowcase
# Pillowcase with Pin-tucks
# Cotton Percale Flat Sheet
# Cotton Satin Pillowcase
# Cotton Satin Duvet Cover
# Cotton Percale Flat Sheet
# Jacquard-weave Pillowcase
# Twin Duvet Cover
# Cotton Satin Duvet Cover
# Oxford-style Pillowcase
# King/Queen Duvet Cover
# Jacquard-weave Pillowcase
# Jacquard-weave Cushion Cover
# Oxford-style Pillowcase
# Cotton Satin Duvet Cover
# Metal Candlestick
# Cotton Satin Duvet Cover
# Jacquard-weave Duvet Cover
# Linen Bedspread
# Pillowcase with Printed Text
# Small Wooden Cutting Board
